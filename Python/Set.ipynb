# %% [markdown]
# # Set Basics

# %%
A={5,6,7,8}
B={1,2,3,4,5,6}
for i in A:
    print(i)
    
    
print(1 in (B))

# %%
Z=A.add(9)

print(A)
A.remove(9)
print(A)

# %%
A.issubset(B)
B.issubset(A)
Z=A|B #A.union(B)
print(Z)
X=A&B #A.intersection(B)
print(X)
z=A.symmetric_difference(B)
print(z)
A.difference(B) #A-B
print(A)
X1=frozenset(A)

# %%
z=lambda x:x*x
z(5)

# %% [markdown]
# # dhruvpython.pythonanywhere.com for python quiz

# %%
d={}
x=input("Enter String")

for i in x:
    d[i]=x.count(i)
    
Z=sorted(d.items(),key=lambda i:i[0])    
print(Z)
# Out:
# Enter StringADBC
# [('A', 1), ('B', 1), ('C', 1), ('D', 1)]

# %%
d={"a":10,"b":20,"c":40,"D":30}
Z=sorted(d.items(),key=lambda i:i[0],reverse=True)    
print(Z)
# Out:
# [('c', 40), ('b', 20), ('a', 10), ('D', 30)]
