# %%
import  numpy as np
l1=[1,2,3,4,5]
x=np.array(l1)
print(x)
print("Type",type(x))
print("Dimension",x.ndim)
# Out:
# [1 2 3 4 5]
# Type <class 'numpy.ndarray'>
# Dimension 1

# %%
l1=[[1,2,3,4,5],[2,3,4,5,6]]
x=np.array(l1)
print(x)
print("Type",type(x))
print("Dimension",x.ndim)
# Out:
# [[1 2 3 4 5]
#  [2 3 4 5 6]]
# Type <class 'numpy.ndarray'>
# Dimension 2

# %%
l1=[[[1,2,3,4,5],[2,3,4,5,6]],[[1,2,3,4,5],[2,3,4,5,6]]]
x1=np.array(l1)
print(x1)
print("Type",type(x1))
print("Dimension",x1.ndim)
# Out:
# [[[1 2 3 4 5]
#   [2 3 4 5 6]]
#
#  [[1 2 3 4 5]
#   [2 3 4 5 6]]]
# Type <class 'numpy.ndarray'>
# Dimension 3

# %%
np.where(x>5)
# Out:
# (array([1], dtype=int64), array([4], dtype=int64))

# %%
np.sort(x1,axis=0)
# Out:
# array([[[1, 2, 3, 4, 5],
#         [2, 3, 4, 5, 6]],
#
#        [[1, 2, 3, 4, 5],
#         [2, 3, 4, 5, 6]]])

# %%
np.sort(x1,axis=1)
# Out:
# array([[[1, 2, 3, 4, 5],
#         [2, 3, 4, 5, 6]],
#
#        [[1, 2, 3, 4, 5],
#         [2, 3, 4, 5, 6]]])

# %%
l1=[1,2,3,4,5,6]
x=np.array(l1)
x2=x1.reshape(4,-1)
print(x2)
# Out:
# [[1 2 3 4 5]
#  [2 3 4 5 6]
#  [1 2 3 4 5]
#  [2 3 4 5 6]]
