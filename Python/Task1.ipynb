# %%
f=open("2","r")
x=f.read()
f.close()
f=open("3.txt","w")
f.write(x)
f.close()

# %%
f=open("new.txt","w+")
f.write("ABC\n DEF")
f.seek(0)
x1=f.read()
f.close()

x1=x1[::-1]
f=open("5.txt","w+")
f.write(x1)
f.seek(0)
y=f.read()
f.close()
print(y)
# Out:
# FED
# CBA

# %%
f=open("One.txt","w+")
f.write(" Content of file 1 :- \n Hello\n How Are You?\n I Am Fine\n GFHGJKHKJHk \nDGFHJGNb\n")
f.seek(0)
x=f.read()
f.close()
f=open("Two.txt","w+")
f.write("\nThis is content of file 2 \n 111111\n dkvmcn m\n rvhdc jsxb\n GFHGJKHKJHk \nDGFHJGNb")
f.seek(0)
y=f.read()
f.close()
f=open("Three.txt","w+")
f.write(x)
f.write(y)
f.seek(0)
z=f.read()
f.close()
print(z)
# Out:
#  Content of file 1 :-
#  Hello
#  How Are You?
#  I Am Fine
#  GFHGJKHKJHk
# DGFHJGNb
#
# This is content of file 2
#  111111
#  dkvmcn m
#  rvhdc jsxb
#  GFHGJKHKJHk
# DGFHJGNb

# %%
f=open("7.txt","w+")
f.write("Programing in Python \n Data Science is Important \n Artificial Intelligence is Future")
f.seek(0)
x=f.read()
f.seek(0)
f.close()
f=open("8.txt","w+")
x=x.split(" ")

for i in x:
    y=i[0].upper()+i[1:-1]+i[-1].upper()+" "
    f.write(y)
 
 
f.close()
f=open("8.txt","r")
x11=f.read()
f.close()
print(x11)
# Out:
# PrograminG IN PythoN
#
#  DatA SciencE IS ImportanT
#
#  ArtificiaL IntelligencE IS FuturE

# %%
f=open("8.txt","r")
x=f.read()
f.close()
print("No of Characters",len(x))
# Out:
# No of Characters 87
