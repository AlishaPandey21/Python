# %%
from datetime import date,time,datetime
x=datetime.now()
print(x)
# Out:
# 2025-12-04 13:23:48.636721

# %%
z=date.today()
print(z)
# Out:
# 2025-12-04

# %%
y=x.time()
print(y)
# Out:
# 13:23:48.636721

# %%
a=datetime(2025,12,31,15,10,59)
print(a)
# Out:
# 2025-12-31 15:10:59

# %%
b=date(2005,12,21)
x=datetime.now()
print(x.date()-b)
# Out:
# 7288 days, 0:00:00
