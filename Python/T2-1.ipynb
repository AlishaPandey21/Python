# %%
x="Happy New Year"
p=x[-10]
print(x[-3])
print(x[1:-1])
print(x[6:9:-1])
print(x[::-1])
# Out:
# e
# appy New Yea
#
# raeY weN yppaH

# %%
a=input("Enter String")
length=len(a)
if length%2!=0:
    print(a[0]+a[-1])
else:
    print(a[-1]+a[1:-1]+a[0])
# Out:
# Enter Stringhell
# lelh

# %%
a="ABC ADEF AGHI"
print(a.count("A"))
print(a.count("A",1,6))
print(a.count(" ",0,7))
# Out:
# 3
# 1
# 1

# %%
a=input("ENTER STRING ")
Count_of_a=a.count("a")
if Count_of_a%2==0:
      ans=a.split("a")
        print(ans)
        y=a.split("")
        print(len(a))
        print(len(y))
  #  else:
  #       ans=a.replace("@").lower()
  #      print(ans)
# Out:
#   File "<ipython-input-29-2f23bab89731>", line 5
#     print(ans)
#     ^
# IndentationError: unexpected indent

# %%
a="Dhruv Dhoni"
m=a.find("r")
if m==-1:
    print("NotFound")
else:
    print(m)
# Out:
# 2

# %%
x="Hello How Are You&"
x1="dgcfhvbkgfn123"

x2="gfjbvjkfcngv"
x3="123"
print(x1.isalnum())
print(x2.isalpha())
print(x3.isdigit())
print(x3.isnumeric())
print(x.isupper())
print(x1.islower())
print(x.istitle())
# Out:
# True
# True
# True
# True
# False
# True
# True

# %%
pass=input("Enter Password")
for i in pass:
if pass.length()<8:
