# %% [markdown]
# # Task

# %%
class SQ:
    def __init__(self):
        self.l=[1,2,3,4]
    def shift(self):
        try:
            
            if len(self.l)==0:
                raise Exception("Lsit is Empty")
           
        except Exception as d:
            print(d)
        else:
            x=self.l.pop(0)
            print("Removed Element is",x)
            print("Updated List is",self.l)

        
    def unshift(self):
        i=int(input("Enter Value to insert"))
        self.l.insert(0,i)
        print("After Unshift",self.l)
        
        
    def push(self):
        i=int(input("Enter Value to insert"))
        self.l.append(i)
        print("ELement is pushed",self.l)
        
      
    def pop(self):
        x1=self.l.pop()
        print("After Pop",self.l)
        
       
    def remove(self):
        z=max(self.l)
        self.l.remove(z)
        print("After Removing",self.l)
       


    
s=SQ()
s.shift()
s.unshift()
s.push()
s.pop()
s.remove()
# Out:
# Removed Element is 1
# Updated List is [2, 3, 4]
# Enter Value to insert2
# After Unshift [2, 2, 3, 4]
# Enter Value to insert3
# ELement is pushed [2, 2, 3, 4, 3]
# After Pop [2, 2, 3, 4]
# After Removing [2, 2, 3]

# %%
class WordPlay:
    def __init__(self,l):
        self.l=l
        print("Given List is ",self.l)
    def words_with_length(self,len1):
        l1=[]
        for i in self.l:
            if len(i)==len1:
                
                l1.append(i)
        print("Length ",l1)
        
    def starts_with(self,char1):
        
        l1=[]
        for i in self.l:
            if i[0]==char1:
                l1.append(i)
        print("Starts with",l1)
    def ends_with(self,char2):
        l1=[]
        for i in self.l:
            if i[-1]==char2:
                l1.append(i)
        print("Ends with",l1)
        
    def palindromes(self):
        l1=[]
        for i in self.l:
            if i==i[::-1]:
                l1.append(i)
        print("Palindromes",l1)
#         l2=[]
#         for i in self.l:
#             l1=i[::-1]
#             if l1==i:
#                 l2.append(i)
#         print(l2)
        
       
            
    def only(self,str1):
        l1=[]
        x=set(str1)
        for i in self.l:
            y=set(i)
            if x.intersection(y)==x:
                l1.append(i)
        print("Only",l1)
                
        
    def avoids(self,str2):
        l1=[]
        x=set(str2)
        for i in self.l:
            y=set(i)
            if x.intersection(y)==set():
                l1.append(i)
        print("Avoid",l1)
       
w=WordPlay(['apple','banana','find','dictionary','set','tuple','list','malayalam','nayan','grind','apricot'])
w.words_with_length(5)
w.starts_with('a')
w.ends_with('d')
w.palindromes()
w.only('bna')
w.avoids('amkd')
# Out:
# Given List is  ['apple', 'banana', 'find', 'dictionary', 'set', 'tuple', 'list', 'malayalam', 'nayan', 'grind', 'apricot']
# Length  ['apple', 'tuple', 'nayan', 'grind']
# Starts with ['apple', 'apricot']
# Ends with ['find', 'grind']
# Palindromes ['malayalam', 'nayan']
# Only ['banana']
# Avoid ['set', 'tuple', 'list']
