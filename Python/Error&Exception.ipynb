# %%
a=10
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b3649862defd> in <module>
#       1 a=10
# ----> 2 print(x)
#
# NameError: name 'x' is not defined

# %%
a=10
b="hello"
a+b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-7f8d005e6541> in <module>
#       1 a=10
#       2 b="hello"
# ----> 3 a+b
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
a=100
b=0
a/b
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-3-2486ea349062> in <module>
#       1 a=100
#       2 b=0
# ----> 3 a/b
#
# ZeroDivisionError: division by zero

# %%
print("Hello)
# Out:
#   File "<ipython-input-5-e8dd6fae58d9>", line 1
#     print("Hello)
#                  ^
# SyntaxError: EOL while scanning string literal

# %%
print("ABC")
   print("hdskvkdf")
# Out:
#   File "<ipython-input-6-7d760cbd5d7b>", line 2
#     print("hdskvkdf")
#     ^
# IndentationError: unexpected indent

# %%
a="Hello"
b=int(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-65bf4f6f7ed2> in <module>
#       1 a="Hello"
# ----> 2 b=int(a)
#
# ValueError: invalid literal for int() with base 10: 'Hello'

# %%
d={"1":"A","2":"b"}
d[100]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-cd9814257e2f> in <module>
#       1 d={"1":"A","2":"b"}
# ----> 2 d[100]
#
# KeyError: 100

# %%
l=[1,2,3]
print(l[100])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-cb60e1e91fa3> in <module>
#       1 l=[1,2,3]
# ----> 2 print(l[100])
#
# IndexError: list index out of range

# %%
l=[1,2,3]
l.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-75e5d8703574> in <module>
#       1 l=[1,2,3]
# ----> 2 l.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
import os2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-dcc9586c002d> in <module>
# ----> 1 import os2
#
# ModuleNotFoundError: No module named 'os2'

# %%
try:
    f=open("1.txt")
except exception as e:
    print(e)
else:
    x=f.read()
    print(x)
finally:
    print("Finally Block ")
# Out:
# AAALO!!!
# How Are You?
# Finally Block

# %%
try:
    a=10
    b=0
    a/b
except Exception as e:
    print(e)
finally:
    print("Complete")
# Out:
# division by zero
# Complete

# %%
try:
    a=10
    b=0
    c=a/b
    print(d)
except ZeroDivisionError as e:
    print("z")
except NameError as e:
    print(e)
# Out:
# z

# %%
class Demo(Exception):
    pass
try:
    n=int(input("Enter Phone Number"))
     
    n=str(n)
    print(n[0])
    if n[0]!=9:
            raise Demo("Please. ")
  
    if len(n)<10 or len(n)>10:
        raise Demo("Please Enter 10 digit Phone no. ")
        
        
    else:
        print("Success")
except Demo as d:
    print(d)
# Out:
# Enter Phone Number0123456789
# 1
# Please.
