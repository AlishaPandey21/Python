# %%
f=open("file.txt") #BY DEFAULT IN READ MODE
x=f.readlines()
f.close()
# print(x)
for i in  x:
    if "#" in i:
        y=i.find("#") 
        x1=i[:y]
        print(x1)
    else:
        f1.write(i)
# Out:
# Hello
#
#
# How are You
#
# This is File1

# %%
f=open("file.txt")
f1=open("File2.txt","w")
for i in x:
    if i[0]=="#":
        continue
    else:
        if "#" in i:
            y=i.find("#") 
            x1=i[0:y]
            print(x1)
        else:
            f1.write(i)

f.close()

f1.close()

# %%
d={}
f=open("File3.txt","w+")
f.write("Dhoni 1000\n D 100\n")
f.seek(0)
f.read()
print(x)
f.close()

# %%
f=open("File3.txt","w+") 

x=f.read()
x1=x.split()
print(x)
f.close()
