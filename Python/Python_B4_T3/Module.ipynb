# %%
import os

# %%
os.getcwd()

# %%
os.chdir(r"C:\Users\LJENG\Desktop\B4")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\LJENG\\Desktop\\B4'

# %%
os.mkdir("T3")

# %%
# %%writefile 1.txt
# Hello
# Out:
# Writing 1.txt

# %%
os.rename("1.txt","demo.txt")

# %%
os.remove(os.getcwd()+"//demo.txt")

# %%
os.rmdir(r"C:\Users\LJENG\Desktop\B4\T3")

# %%
os.rmdir(r"C:\Users\LJENG\Desktop\B4")

# %%
os.listdir(r"C:\inetpub")
# Out:
# ['history', 'logs', 'temp', 'wwwroot']

# %%
os.getcwd()
# Out:
# 'C:\\Users\\LJENG\\Desktop\\Python_B4_T3'

# %%
os.chdir(r"C:\Users\LJENG\Desktop\7")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\LJENG\\Desktop\\7'

# %%
os.mkdir("1")
os.mkdir("2")
os.mkdir("3")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-17-580efff81740> in <module>
# ----> 1 os.mkdir("1")
#       2 os.mkdir("2")
#       3 os.mkdir("3")
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: '1'

# %%
os.chdir(r"C:\Users\LJENG\Desktop\7\1")
os.getcwd()
# Out:
# 'C:\\Users\\LJENG\\Desktop\\7\\1'
