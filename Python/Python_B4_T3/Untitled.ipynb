# %%
import os

# %%
# %%writefile ae.py
a="Hello"
b=10
def length(a):
    return len(a)
def rev(a):
    return a[::-1]

# %%
import ae
ae.b

# %%
import ae as p
input1=input("Enter String to count for length")
p.length(input1)

# %%
from ae import b
print(b)

# %%
from ae import *

print(rev("Hello"))
print(length("Hello"))

# %%
# %%writefile first_word.py
def ret(a):
    y=a.split()
    return y[0]
# Out:
# Overwriting first_word.py

# %%
import first_word as p
x=input("Input the String")
x1="This bujj hhihji"
print(p.ret(x1))
# Out:
# Input the Stringfhug
# This
