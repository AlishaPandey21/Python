# %% [markdown]
# # INTRODUCTION TO ML

# %% [markdown]
# # FROM DIABETES DATASET

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("diabetes_unclean.csv")

# %%
df
# Out:
#        ID  No_Pation Gender   AGE  Urea    Cr  HbA1c  Chol   TG  HDL  LDL  \
# 0     502      17975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 1     735      34221      M  26.0   4.5  62.0    4.9   3.7  1.4  1.1  2.1
# 2     420      47975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 3     680      87656      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 4     504      34223      M  33.0   7.1  46.0    4.9   4.9  1.0  0.8  2.0
# ...   ...        ...    ...   ...   ...   ...    ...   ...  ...  ...  ...
# 1004  191     454316      M  55.0   NaN  62.0    6.8   5.3  2.0  1.0  3.5
# 1005  192     454316      M  55.0   4.8  88.0    NaN   5.7  4.0  0.9  3.3
# 1006  193     454316      M  62.0   6.3  82.0    6.7   5.3  2.0  1.0  3.5
# 1007  194     454316      F  57.0   4.1  70.0    9.3   5.3  3.3  1.0  1.4
# 1008  195       4543      f  55.0   4.1  34.0   13.9   5.4  1.6  1.6  3.1
#
#       VLDL   BMI CLASS
# 0      0.5  24.0     N
# 1      0.6  23.0     N
# ...

# %%
df.isnull().sum()
# Out:
# ID           0
# No_Pation    0
# Gender       0
# AGE          1
# Urea         1
# Cr           2
# HbA1c        3
# Chol         2
# TG           2
# HDL          1
# LDL          2
# VLDL         1
# BMI          0
# CLASS        0
# dtype: int64

# %%
df.isna().sum()
# Out:
# ID           0
# No_Pation    0
# Gender       0
# AGE          1
# Urea         1
# Cr           2
# HbA1c        3
# Chol         2
# TG           2
# HDL          1
# LDL          2
# VLDL         1
# BMI          0
# CLASS        0
# dtype: int64

# %%
df.dtypes
# Out:
# ID             int64
# No_Pation      int64
# Gender        object
# AGE          float64
# Urea         float64
# Cr           float64
# HbA1c        float64
# Chol         float64
# TG           float64
# HDL          float64
# LDL          float64
# VLDL         float64
# BMI          float64
# CLASS         object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         1009 non-null   int64
#  1   No_Pation  1009 non-null   int64
#  2   Gender     1009 non-null   object
#  3   AGE        1008 non-null   float64
#  4   Urea       1008 non-null   float64
#  5   Cr         1007 non-null   float64
#  6   HbA1c      1006 non-null   float64
#  7   Chol       1007 non-null   float64
#  8   TG         1007 non-null   float64
#  9   HDL        1008 non-null   float64
#  10  LDL        1007 non-null   float64
#  11  VLDL       1008 non-null   float64
#  12  BMI        1009 non-null   float64
#  13  CLASS      1009 non-null   object
# dtypes: float64(10), int64(2), object(2)
# memory usage: 110.5+ KB

# %%
df=df.fillna(df.mean(numeric_only=True))
df
# Out:
#        ID  No_Pation Gender   AGE      Urea    Cr      HbA1c  Chol   TG  HDL  \
# 0     502      17975      F  50.0  4.700000  46.0   4.900000   4.2  0.9  2.4
# 1     735      34221      M  26.0  4.500000  62.0   4.900000   3.7  1.4  1.1
# 2     420      47975      F  50.0  4.700000  46.0   4.900000   4.2  0.9  2.4
# 3     680      87656      F  50.0  4.700000  46.0   4.900000   4.2  0.9  2.4
# 4     504      34223      M  33.0  7.100000  46.0   4.900000   4.9  1.0  0.8
# ...   ...        ...    ...   ...       ...   ...        ...   ...  ...  ...
# 1004  191     454316      M  55.0  5.131094  62.0   6.800000   5.3  2.0  1.0
# 1005  192     454316      M  55.0  4.800000  88.0   8.284155   5.7  4.0  0.9
# 1006  193     454316      M  62.0  6.300000  82.0   6.700000   5.3  2.0  1.0
# 1007  194     454316      F  57.0  4.100000  70.0   9.300000   5.3  3.3  1.0
# 1008  195       4543      f  55.0  4.100000  34.0  13.900000   5.4  1.6  1.6
#
#       LDL      VLDL   BMI CLASS
# ...

# %%
df.isnull().sum()
# Out:
# ID           0
# No_Pation    0
# Gender       0
# AGE          0
# Urea         0
# Cr           0
# HbA1c        0
# Chol         0
# TG           0
# HDL          0
# LDL          0
# VLDL         0
# BMI          0
# CLASS        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# ID           800
# No_Pation    961
# Gender         3
# AGE           50
# Urea         111
# Cr           114
# HbA1c        112
# Chol          78
# TG            70
# HDL           49
# LDL           66
# VLDL          61
# BMI           64
# CLASS          5
# dtype: int64

# %%
df.value_counts("Gender")
# Out:
# Gender
# M    570
# F    437
# f      2
# Name: count, dtype: int64

# %%
df.value_counts()
# Out:
# ID   No_Pation  Gender  AGE   Urea  Cr     HbA1c  Chol  TG   HDL  LDL  VLDL  BMI    CLASS
# 1    34325      M       56.0  20.8  800.0  9.0    4.6   2.0  1.2  2.5  0.9   35.00  Y        1
# 470  46675      F       30.0  3.0   45.0   4.1    4.9   1.3  1.2  3.2  0.5   22.00  N        1
# 457  48312      M       51.0  3.3   41.0   13.9   6.0   1.1  1.4  1.3  0.4   27.17  Y        1
# 458  34242      F       39.0  3.2   55.0   5.0    4.6   1.3  1.0  3.0  0.6   21.00  N        1
# 459  48353      M       67.0  13.3  107.0  7.1    3.0   2.2  0.8  1.3  1.0   27.00  Y        1
#                                                                                             ..
# 171  45434      M       40.0  22.0  159.0  5.4    3.1   1.6  1.1  1.3  0.7   24.00  N        1
# 172  34509      M       60.0  5.1   62.0   12.3   6.1   3.8  1.1  3.5  1.7   38.00  Y        1
#      45372      M       30.0  13.2  185.0  8.1    5.0   1.1  1.8  4.1  1.0   21.00  Y        1
# ...

# %%
df['Gender']=df["Gender"].replace("f","F")

# %%
df
# Out:
#        ID  No_Pation Gender   AGE      Urea    Cr      HbA1c  Chol   TG  HDL  \
# 0     502      17975      F  50.0  4.700000  46.0   4.900000   4.2  0.9  2.4
# 1     735      34221      M  26.0  4.500000  62.0   4.900000   3.7  1.4  1.1
# 2     420      47975      F  50.0  4.700000  46.0   4.900000   4.2  0.9  2.4
# 3     680      87656      F  50.0  4.700000  46.0   4.900000   4.2  0.9  2.4
# 4     504      34223      M  33.0  7.100000  46.0   4.900000   4.9  1.0  0.8
# ...   ...        ...    ...   ...       ...   ...        ...   ...  ...  ...
# 1004  191     454316      M  55.0  5.131094  62.0   6.800000   5.3  2.0  1.0
# 1005  192     454316      M  55.0  4.800000  88.0   8.284155   5.7  4.0  0.9
# 1006  193     454316      M  62.0  6.300000  82.0   6.700000   5.3  2.0  1.0
# 1007  194     454316      F  57.0  4.100000  70.0   9.300000   5.3  3.3  1.0
# 1008  195       4543      F  55.0  4.100000  34.0  13.900000   5.4  1.6  1.6
#
#       LDL      VLDL   BMI CLASS
# ...

# %%
df["Gender"].value_counts()
# Out:
# Gender
# M    570
# F    439
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
y=df[['CLASS']]
y.shape
# Out:
# (1009, 1)

# %%
y
# Out:
#      CLASS
# 0        N
# 1        N
# 2        N
# 3        N
# 4        N
# ...    ...
# 1004    Y
# 1005    Y
# 1006    Y
# 1007    Y
# 1008    Y
#
# [1009 rows x 1 columns]

# %%
x=df.drop(columns=["ID","No_Pation",'CLASS'])

# %%
x
# Out:
#      Gender   AGE      Urea    Cr      HbA1c  Chol   TG  HDL  LDL      VLDL  \
# 0         F  50.0  4.700000  46.0   4.900000   4.2  0.9  2.4  1.4  0.500000
# 1         M  26.0  4.500000  62.0   4.900000   3.7  1.4  1.1  2.1  0.600000
# 2         F  50.0  4.700000  46.0   4.900000   4.2  0.9  2.4  1.4  0.500000
# 3         F  50.0  4.700000  46.0   4.900000   4.2  0.9  2.4  1.4  0.500000
# 4         M  33.0  7.100000  46.0   4.900000   4.9  1.0  0.8  2.0  0.400000
# ...     ...   ...       ...   ...        ...   ...  ...  ...  ...       ...
# 1004      M  55.0  5.131094  62.0   6.800000   5.3  2.0  1.0  3.5  0.900000
# 1005      M  55.0  4.800000  88.0   8.284155   5.7  4.0  0.9  3.3  1.800000
# 1006      M  62.0  6.300000  82.0   6.700000   5.3  2.0  1.0  3.5  1.850595
# 1007      F  57.0  4.100000  70.0   9.300000   5.3  3.3  1.0  1.4  1.300000
# 1008      F  55.0  4.100000  34.0  13.900000   5.4  1.6  1.6  3.1  0.700000
#
#        BMI
# 0     24.0
# 1     23.0
# 2     24.0
# ...

# %%
x_train,y_train,x_test,y_test=train_test_split(x,y)
print(x_train)
print("-----------------------------------------------")
print(y_train)
# Out:
#     Gender   AGE  Urea    Cr  HbA1c  Chol   TG  HDL  LDL  VLDL    BMI
# 798      F  63.0  2.80  54.0   11.2   4.2  1.1  1.7  1.4   2.0  36.00
# 678      F  56.0  2.30  22.0   10.2   5.8  2.0  1.1  1.8   0.9  27.00
# 358      M  61.0  4.70  58.0    6.4   4.4  2.1  0.7  2.9   0.9  26.00
# 532      M  55.0  4.66  70.0    7.5   7.3  1.6  1.2  5.5  11.3  36.11
# 282      F  53.0  4.50  68.0    6.9   5.4  3.8  1.9  3.0   0.7  39.00
# ..     ...   ...   ...   ...    ...   ...  ...  ...  ...   ...    ...
# 306      F  59.0  4.70  55.0    7.0   3.4  1.8  1.1  1.8   0.8  26.00
# 541      M  60.0  2.10  56.0    7.6   3.3  1.7  0.9  1.7   0.8  36.60
# 459      M  51.0  6.10  56.0    8.0   4.9  2.1  1.1  2.5   0.9  28.00
# 401      M  60.0  5.70  76.0    6.8   5.5  1.5  0.7  4.1   0.7  33.00
# 58       F  49.0  2.10  38.0    5.0   4.2  0.8  0.9  3.0   0.4  21.00
#
# [756 rows x 11 columns]
# -----------------------------------------------
# ...

# %%
print("--"*50)
print("X_test")
print("--"*50)

print(x_test)
print("--"*50)
print("y_test")
print("--"*50)


print(y_test)
print("--"*50)
# Out:
# ----------------------------------------------------------------------------------------------------
# X_test
# ----------------------------------------------------------------------------------------------------
#     CLASS
# 798     Y
# 678     Y
# 358     Y
# 532     Y
# 282     Y
# ..    ...
# 306     Y
# 541     Y
# 459     Y
# 401     Y
# 58      N
#
# [756 rows x 1 columns]
# ----------------------------------------------------------------------------------------------------
# y_test
# ----------------------------------------------------------------------------------------------------
#     CLASS
# 217     Y
# 968     Y
# 449     Y
# 404     Y
# 344     Y
# ..    ...
# 158     Y
# 402     Y
# 657     Y
# 661     Y
# 497     Y
#
# [253 rows x 1 columns]
# ----------------------------------------------------------------------------------------------------

# %%
x_train.shape
# Out:
# (756, 11)

# %%
x_test.shape
# Out:
# (756, 1)

# %%
print("--"*50)

print("FOR TEST SIZE 0.2")
print("--"*50)

x_train,y_train,x_test,y_test=train_test_split(x,y,test_size=0.2)
print(x_train)
print("--"*50)

print(y_train)
print("--"*50)
# Out:
# ----------------------------------------------------------------------------------------------------
# FOR TEST SIZE 0.2
# ----------------------------------------------------------------------------------------------------
#     Gender   AGE  Urea     Cr  HbA1c  Chol   TG  HDL  LDL  VLDL   BMI
# 354      M  55.0   4.8   63.0    6.7   3.4  0.7  1.1  2.0   0.3  30.0
# 639      M  61.0   5.9   56.0   10.9   4.6  7.0  0.6  1.3   3.1  30.0
# 267      M  55.0   5.1   78.0   11.8   4.5  1.8  1.1  2.7  12.7  31.5
# 60       F  48.0   2.8   55.0    5.0   3.6  0.6  2.1  1.2   0.2  23.5
# 157      M  30.0   7.1   81.0    6.7   4.1  1.1  1.2  2.4   8.1  27.4
# ..     ...   ...   ...    ...    ...   ...  ...  ...  ...   ...   ...
# 283      M  58.0  20.8  800.0    9.1   6.6  2.9  1.1  4.3   1.3  33.0
# 166      M  35.0   4.8   64.0    7.7   3.7  1.0  1.2  2.0   7.2  27.3
# 342      M  58.0   4.8   60.0    5.5   0.6  2.5  1.1  2.0   0.6  38.0
# ...

# %%
print("--"*50)

print("FOR TEST SIZE 0.2 and Random State")
print("--"*50)

x_train,y_train,x_test,y_test=train_test_split(x,y,test_size=0.2,random_state=10)
print(x_train)
print("--"*50)

print(y_train)
print("--"*50)
# Out:
# ----------------------------------------------------------------------------------------------------
# FOR TEST SIZE 0.2 and Random State
# ----------------------------------------------------------------------------------------------------
#     Gender   AGE  Urea     Cr  HbA1c  Chol        TG  HDL  LDL  VLDL   BMI
# 724      M  54.0   5.4   68.0    3.0   1.2  0.700000  1.0  0.5   1.5  33.0
# 951      F  55.0   6.6  168.0    7.0   4.0  2.348769  1.0  2.0   1.0  33.0
# 837      M  53.0   3.8   59.0   10.9   5.1  3.200000  1.8  2.0   1.0  28.0
# 815      F  59.0   6.0   28.0   14.6   6.1  4.400000  1.2  1.3   2.0  29.0
# 252      F  61.0   2.1   23.0    9.9   4.1  4.200000  1.2  1.4   1.1  28.0
# ..     ...   ...   ...    ...    ...   ...       ...  ...  ...   ...   ...
# 320      M  60.0   6.5   30.0    9.0   5.9  3.400000  0.8  3.7   0.5  30.0
# 527      M  52.0   4.9   68.0   10.2   5.9  2.900000  1.0  3.6   1.3  39.0
# ...

# %% [markdown]
# # FROM CAR DATA DATASET

# %%
df=pd.read_csv("car data.csv")

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (299, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 299 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       299 non-null    object
#  1   Year           299 non-null    int64
#  2   Selling_Price  299 non-null    float64
#  3   Present_Price  299 non-null    float64
#  4   Kms_Driven     299 non-null    int64
#  5   Fuel_Type      299 non-null    object
#  6   Seller_Type    299 non-null    object
#  7   Transmission   299 non-null    object
#  8   Owner          299 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 23.4+ KB

# %%
df["Car_Name"].value_counts()
# Out:
# Car_Name
# city                        26
# corolla altis               16
# verna                       14
# brio                        10
# fortuner                    10
#                             ..
# Honda CB Trigger             1
# Yamaha FZ S                  1
# Bajaj Pulsar 135 LS          1
# Activa 4g                    1
# Bajaj Avenger Street 220     1
# Name: count, Length: 98, dtype: int64

# %%
df["Transmission"].nunique()
# Out:
# 2

# %%
import seaborn as sns
sns.scatterplot(data=df,x="Present_Price",y= "Selling_Price")
# Out:
# <Axes: xlabel='Present_Price', ylabel='Selling_Price'>

# %%
x=df[["Present_Price"]]
y=df[["Selling_Price"]]

# %%
x_train,y_train,x_test,y_test=train_test_split(x,y)

# %%
print(x_train)
print("--"*50)

print(y_train)
print("--"*50)
# Out:
#      Present_Price
# 105           2.37
# 173           0.51
# 171           0.55
# 190           0.75
# 162           0.99
# ..             ...
# 285           8.50
# 296          11.60
# 61            7.70
# 48            7.71
# 71           12.48
#
# [224 rows x 1 columns]
# ----------------------------------------------------------------------------------------------------
#      Present_Price
# 31           4.890
# 288         13.600
# 238          9.400
# 277         13.600
# 101          1.820
# ..             ...
# 278          8.400
# 276         13.600
# 251          9.900
# 254          9.900
# 146          0.787
#
# [75 rows x 1 columns]
# ----------------------------------------------------------------------------------------------------

# %%
x_train,y_train,x_test,y_test=train_test_split(x,y,random_state=42,train_size=0.8)
print("--"*50)
print("FOR RANDOM STATE AND TRAIN SIZE 42 and 0.8 RESPECTIVElY")
print("--"*50)
print("--"*50)

print("TRAIN DATA")
print("--"*50)
print("--"*50)

print("x_train")
print("--"*50)
print(x_train)
print("--"*50)
print("y_train")
print("--"*50)
print(y_train)
print("--"*50)
print("--"*50)

print("TEST DATA")
print("--"*50)

print("--"*50)
print("x_test")
print("--"*50)
print(x_test)
print("--"*50)
print("y_test")
print("--"*50)
print(y_test)
print("--"*50)
# Out:
# ----------------------------------------------------------------------------------------------------
# FOR RANDOM STATE AND TRAIN SIZE 42 and 0.8 RESPECTIVElY
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# TRAIN DATA
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# x_train
# ----------------------------------------------------------------------------------------------------
#      Present_Price
# 6             8.12
# 185           0.58
# 187           0.51
# 148           0.94
# 31            4.89
# ..             ...
# 190           0.75
# 72           18.61
# 108           1.50
# 272          10.00
# 104           1.47
#
# [239 rows x 1 columns]
# ...

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
print("--"*50)
print("UNIQUE VALUE COUNT OF Fuel_Type")
print("--"*50)

print(df["Fuel_Type"].nunique())
print("--"*50)
print("UNIQUE VALUE COUNT OF Seller_Type ")
print("--"*50)

print(df["Seller_Type"].nunique())
print("--"*50)
print("UNIQUE VALUE COUNT OF Transmission")
print("--"*50)
print(df["Transmission"].nunique())
print("--"*50)
print("UNIQUE VALUE COUNT OF Car_Name ")
print("--"*50)
print(df["Car_Name"].nunique())
print("--"*50)
# Out:
# ----------------------------------------------------------------------------------------------------
# UNIQUE VALUE COUNT OF Fuel_Type
# ----------------------------------------------------------------------------------------------------
# 3
# ----------------------------------------------------------------------------------------------------
# UNIQUE VALUE COUNT OF Seller_Type
# ----------------------------------------------------------------------------------------------------
# 2
# ----------------------------------------------------------------------------------------------------
# UNIQUE VALUE COUNT OF Transmission
# ----------------------------------------------------------------------------------------------------
# 2
# ----------------------------------------------------------------------------------------------------
# UNIQUE VALUE COUNT OF Car_Name
# ----------------------------------------------------------------------------------------------------
# 98
# ...

# %%
x=df.drop(columns=["Selling_Price","Owner","Car_Name"])

# %%
x
# Out:
#      Year  Present_Price  Kms_Driven Fuel_Type Seller_Type Transmission
# 0    2014           5.59       27000    Petrol      Dealer       Manual
# 1    2013           9.54       43000    Diesel      Dealer       Manual
# 2    2017           9.85        6900    Petrol      Dealer       Manual
# 3    2011           4.15        5200    Petrol      Dealer       Manual
# 4    2014           6.87       42450    Diesel      Dealer       Manual
# ..    ...            ...         ...       ...         ...          ...
# 296  2016          11.60       33988    Diesel      Dealer       Manual
# 297  2015           5.90       60000    Petrol      Dealer       Manual
# 298  2009          11.00       87934    Petrol      Dealer       Manual
# 299  2017          12.50        9000    Diesel      Dealer       Manual
# 300  2016           5.90        5464    Petrol      Dealer       Manual
#
# [299 rows x 6 columns]

# %%
x=pd.get_dummies(x,drop_first=True)
x
# Out:
#      Year  Present_Price  Kms_Driven  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# 0    2014           5.59       27000             False              True
# 1    2013           9.54       43000              True             False
# 2    2017           9.85        6900             False              True
# 3    2011           4.15        5200             False              True
# 4    2014           6.87       42450              True             False
# ..    ...            ...         ...               ...               ...
# 296  2016          11.60       33988              True             False
# 297  2015           5.90       60000             False              True
# 298  2009          11.00       87934             False              True
# 299  2017          12.50        9000              True             False
# 300  2016           5.90        5464             False              True
#
#      Seller_Type_Individual  Transmission_Manual
# ...
